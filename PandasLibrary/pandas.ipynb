# %% [markdown]
# ## Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# pip install seaborn 
import seaborn as sns
  
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Syntax- Load Data from csv

# %%
df = pd.read_csv('weather.csv')
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
# 1       1012.4       1008.4         5         3     17.5     25.7        Yes
# 2       1009.5       1007.2         8         7     15.4     20.2        Yes
# 3       1005.5       1007.0         2         7     13.5     14.1        Yes
# 4       1018.3       1018.5         7         7     11.1     15.4        Yes
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
# 1      3.6          Yes
# 2     39.8          Yes
# 3      2.8          Yes
# 4      0.0           No
#
# [5 rows x 22 columns]

# %%
print(df.shape)
# Out:
# (366, 22)

# %%
print(df.columns)
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
#  17  Temp9am        366 non-null    float64
#  18  Temp3pm        366 non-null    float64
#  19  RainToday      366 non-null    object
#  20  RISK_MM        366 non-null    float64
#  21  RainTomorrow   366 non-null    object
# dtypes: float64(12), int64(5), object(5)
# memory usage: 63.0+ KB
# None

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        366 non-null    float64
#  1   MaxTemp        366 non-null    float64
#  2   Rainfall       366 non-null    float64
#  3   Evaporation    366 non-null    float64
#  4   Sunshine       363 non-null    float64
#  5   WindGustDir    363 non-null    object
#  6   WindGustSpeed  364 non-null    float64
#  7   WindDir9am     335 non-null    object
#  8   WindDir3pm     365 non-null    object
#  9   WindSpeed9am   359 non-null    float64
#  10  WindSpeed3pm   366 non-null    int64
#  11  Humidity9am    366 non-null    int64
#  12  Humidity3pm    366 non-null    int64
#  13  Pressure9am    366 non-null    float64
#  14  Pressure3pm    366 non-null    float64
#  15  Cloud9am       366 non-null    int64
#  16  Cloud3pm       366 non-null    int64
#  17  Temp9am        366 non-null    float64
#  18  Temp3pm        366 non-null    float64
#  19  RainToday      366 non-null    object
#  20  RISK_MM        366 non-null    float64
#  21  RainTomorrow   366 non-null    object
# dtypes: float64(12), int64(5), object(5)
# memory usage: 63.0+ KB
# None

# %%
df['MinTemp'] = df['MinTemp'].astype('int64')

# %%
df.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     6.961749   20.550273    1.428415     4.521858    7.909366
# std      5.829416    6.690516    4.225800     2.669383    3.481517
# min     -5.000000    7.600000    0.000000     0.200000    0.000000
# 25%      2.000000   15.025000    0.000000     2.200000    5.950000
# 50%      7.000000   19.650000    0.000000     4.200000    8.600000
# 75%     12.000000   25.500000    0.200000     6.400000   10.500000
# max     20.000000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# min        13.000000      0.000000      0.000000    36.000000    13.000000
# 25%        31.000000      6.000000     11.000000    64.000000    32.250000
# 50%        39.000000      7.000000     17.000000    72.000000    43.000000
# 75%        46.000000     13.000000     24.000000    81.000000    55.000000
# max        98.000000     41.000000     52.000000    99.000000    96.000000
#
#        Pressure9am  Pressure3pm    Cloud9am    Cloud3pm     Temp9am  \
# count   366.000000   366.000000  366.000000  366.000000  366.000000
# mean   1019.709016  1016.810383    3.890710    4.024590   12.358470
# std       6.686212     6.469422    2.956131    2.666268    5.630832
# min     996.500000   996.800000    0.000000    0.000000    0.100000
# 25%    1015.350000  1012.800000    1.000000    1.000000    7.625000
# 50%    1020.150000  1017.400000    3.500000    4.000000   12.550000
# 75%    1024.475000  1021.475000    7.000000    7.000000   17.000000
# max    1035.700000  1033.200000    8.000000    8.000000   24.700000
#
#           Temp3pm     RISK_MM
# count  366.000000  366.000000
# mean    19.230874    1.428415
# std      6.640346    4.225800
# min      5.100000    0.000000
# 25%     14.150000    0.000000
# 50%     18.550000    0.000000
# 75%     24.000000    0.200000
# max     34.500000   39.800000

# %%
df.describe(include=['object', 'object'])
# Out:
#        WindGustDir WindDir9am WindDir3pm RainToday RainTomorrow
# count          363        335        365       366          366
# unique          16         16         16         2            2
# top             NW         SE        WNW        No           No
# freq            73         47         61       300          300

# %%
df['WindDir9am'].value_counts()
# Out:
# SE     47
# SSE    40
# NNW    36
# N      31
# NW     30
# ESE    29
# S      27
# E      22
# SSW    17
# WNW    16
# NNE     8
# ENE     8
# W       8
# SW      7
# WSW     5
# NE      4
# Name: WindDir9am, dtype: int64

# %%
df['WindDir9am'].value_counts(normalize=True)
# Out:
# SE     0.140299
# SSE    0.119403
# NNW    0.107463
# N      0.092537
# NW     0.089552
# ESE    0.086567
# S      0.080597
# E      0.065672
# SSW    0.050746
# WNW    0.047761
# NNE    0.023881
# ENE    0.023881
# W      0.023881
# SW     0.020896
# WSW    0.014925
# NE     0.011940
# Name: WindDir9am, dtype: float64

# %%
df.sort_values(by='Rainfall', ascending=False).head()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 3         13     15.5      39.8          7.2       9.1          NW
# 22        12     18.5      25.8          2.8       0.6         ESE
# 30        15     20.4      22.6          2.4       0.2         SSE
# 146       12     20.2      19.8          2.6       9.1           W
# 263        2     11.6      19.2          1.8       7.5         WNW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 3             54.0        WNW          W          30.0  ...           56
# 22            28.0          S         SE          13.0  ...           79
# 30            41.0          E          S           6.0  ...           90
# 146           46.0        NNW          W          17.0  ...           50
# 263           54.0        WNW        WNW          26.0  ...           56
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 3         1005.5       1007.0         2         7     13.5     14.1
# 22        1014.0       1014.9         8         8     14.0     16.8
# 30        1015.0       1014.1         8         8     17.0     16.3
# 146       1007.9       1008.4         5         4     15.1     17.4
# 263       1006.9       1010.3         7         3      7.6     11.2
#
#      RainToday  RISK_MM RainTomorrow
# 3          Yes      2.8          Yes
# 22         Yes      0.4           No
# 30         Yes      4.2          Yes
# 146        Yes      0.0           No
# 263        Yes      0.0           No
#
# [5 rows x 22 columns]

# %%
df.sort_values(by=['Rainfall','Sunshine'], ascending=[False,True]).head()
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 3         13     15.5      39.8          7.2       9.1          NW
# 22        12     18.5      25.8          2.8       0.6         ESE
# 30        15     20.4      22.6          2.4       0.2         SSE
# 146       12     20.2      19.8          2.6       9.1           W
# 263        2     11.6      19.2          1.8       7.5         WNW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 3             54.0        WNW          W          30.0  ...           56
# 22            28.0          S         SE          13.0  ...           79
# 30            41.0          E          S           6.0  ...           90
# 146           46.0        NNW          W          17.0  ...           50
# 263           54.0        WNW        WNW          26.0  ...           56
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 3         1005.5       1007.0         2         7     13.5     14.1
# 22        1014.0       1014.9         8         8     14.0     16.8
# 30        1015.0       1014.1         8         8     17.0     16.3
# 146       1007.9       1008.4         5         4     15.1     17.4
# 263       1006.9       1010.3         7         3      7.6     11.2
#
#      RainToday  RISK_MM RainTomorrow
# 3          Yes      2.8          Yes
# 22         Yes      0.4           No
# 30         Yes      4.2          Yes
# 146        Yes      0.0           No
# 263        Yes      0.0           No
#
# [5 rows x 22 columns]

# %%
df['Sunshine'].mean()
# Out:
# 7.909366391184575

# %%
df[df['Sunshine'] > 5].mean()
# Out:
# MinTemp             6.815068
# MaxTemp            21.506164
# Rainfall            1.212329
# Evaporation         4.747260
# Sunshine            9.315068
# WindGustSpeed      40.579310
# WindSpeed9am        9.517483
# WindSpeed3pm       18.373288
# Humidity9am        69.948630
# Humidity3pm        39.414384
# Pressure9am      1019.651370
# Pressure3pm      1016.639726
# Cloud9am            3.092466
# Cloud3pm            3.284247
# Temp9am            12.537671
# Temp3pm            20.239384
# RISK_MM             0.752055
# dtype: float64

# %%
df[df['Sunshine'] > 5]['Humidity9am'].mean()
# Out:
# 69.9486301369863

# %%
df.loc[0:3, 'MinTemp':'Evaporation']
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation
# 0        8     24.3       0.0          3.4
# 1       14     26.9       3.6          4.4
# 2       13     23.4       3.6          5.8
# 3       13     15.5      39.8          7.2

# %%
df.iloc[0:4, 0:4]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation
# 0        8     24.3       0.0          3.4
# 1       14     26.9       3.6          4.4
# 2       13     23.4       3.6          5.8
# 3       13     15.5      39.8          7.2

# %%
df[:1]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8     24.3       0.0          3.4       6.3          NW
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6         No
#
#    RISK_MM RainTomorrow
# 0      3.6          Yes
#
# [1 rows x 22 columns]

# %%
df[-1:]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 365       12     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 365         No      0.0           No
#
# [1 rows x 22 columns]

# %%
filtered_df=df.iloc[0:365, 0:4]
filtered_df.apply(np.max)
# Out:
# MinTemp        20.0
# MaxTemp        35.8
# Rainfall       39.8
# Evaporation    13.8
# dtype: float64

# %%
df['WindGustDir'] = df['WindGustDir'].astype('string')

# %%
df[df['WindGustDir'].apply(lambda windgustdir: windgustdir == 'NW',1)].head()
# Out:
#     MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0         8     24.3       0.0          3.4       6.3          NW
# 2        13     23.4       3.6          5.8       3.3          NW
# 3        13     15.5      39.8          7.2       9.1          NW
# 13       12     30.9       0.0          6.2      12.4          NW
# 14       10     31.2       0.0          8.8      13.1          NW
#
#     WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0            30.0         SW         NW           6.0  ...           29
# 2            85.0          N        NNE           6.0  ...           69
# 3            54.0        WNW          W          30.0  ...           56
# 13           44.0        WNW          W           7.0  ...           20
# 14           41.0          S          W           6.0  ...           16
#
#     Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0        1019.7       1015.0         7         7     14.4     23.6         No
# 2        1009.5       1007.2         8         7     15.4     20.2        Yes
# 3        1005.5       1007.0         2         7     13.5     14.1        Yes
# 13       1017.3       1013.1         1         4     19.7     30.7         No
# 14       1018.2       1013.7         0         1     18.7     30.4         No
#
#     RISK_MM RainTomorrow
# 0       3.6          Yes
# 2      39.8          Yes
# 3       2.8          Yes
# 13      0.0           No
# 14      0.0           No
#
# [5 rows x 22 columns]

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0          8     24.3       0.0          3.4       6.3          NW
# 1         14     26.9       3.6          4.4       9.7         ENE
# 2         13     23.4       3.6          5.8       3.3          NW
# 3         13     15.5      39.8          7.2       9.1          NW
# 4          7     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361        9     30.7       0.0          7.6      12.1         NNW
# 362        7     28.4       0.0         11.6      12.7           N
# 363       12     19.9       0.0          8.4       5.3         ESE
# 364       12     26.9       0.0          5.0       7.1          NW
# 365       12     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 4             50.0        SSE        ESE          20.0  ...           49
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1019.7       1015.0         7         7     14.4     23.6
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 4         1018.3       1018.5         7         7     11.1     15.4
# ..           ...          ...       ...       ...      ...      ...
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM RainTomorrow
# 0           No      3.6          Yes
# 1          Yes      3.6          Yes
# 2          Yes     39.8          Yes
# 3          Yes      2.8          Yes
# 4          Yes      0.0           No
# ..         ...      ...          ...
# 361         No      0.0           No
# 362         No      0.0           No
# 363         No      0.0           No
# 364         No      0.0           No
# 365         No      0.0           No
#
# [366 rows x 22 columns]

# %%
d = {'No' : False, 'Yes' : True}
df['RainToday'] = df['RainToday'].map(d)
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8     24.3       0.0          3.4       6.3          NW
# 1       14     26.9       3.6          4.4       9.7         ENE
# 2       13     23.4       3.6          5.8       3.3          NW
# 3       13     15.5      39.8          7.2       9.1          NW
# 4        7     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6      False
# 1       1012.4       1008.4         5         3     17.5     25.7       True
# 2       1009.5       1007.2         8         7     15.4     20.2       True
# 3       1005.5       1007.0         2         7     13.5     14.1       True
# 4       1018.3       1018.5         7         7     11.1     15.4       True
#
#    RISK_MM  RainTomorrow
# 0      3.6           Yes
# 1      3.6           Yes
# 2     39.8           Yes
# 3      2.8           Yes
# 4      0.0            No
#
# [5 rows x 22 columns]

# %%
d = {'No' : False, 'Yes' : True}
df = df.replace({'RainTomorrow': d})
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8     24.3       0.0          3.4       6.3          NW
# 1       14     26.9       3.6          4.4       9.7         ENE
# 2       13     23.4       3.6          5.8       3.3          NW
# 3       13     15.5      39.8          7.2       9.1          NW
# 4        7     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1019.7       1015.0         7         7     14.4     23.6      False
# 1       1012.4       1008.4         5         3     17.5     25.7       True
# 2       1009.5       1007.2         8         7     15.4     20.2       True
# 3       1005.5       1007.0         2         7     13.5     14.1       True
# 4       1018.3       1018.5         7         7     11.1     15.4       True
#
#    RISK_MM  RainTomorrow
# 0      3.6          True
# 1      3.6          True
# 2     39.8          True
# 3      2.8          True
# 4      0.0         False
#
# [5 rows x 22 columns]

# %%
columns_to_show=df.iloc[:,0:6].columns
df.groupby(['WindGustDir'])[columns_to_show].describe(percentiles=[]).head()
# Out:
#             MinTemp                                       MaxTemp             \
#               count       mean       std  min   50%   max   count       mean
# WindGustDir
# E              37.0   9.621622  4.934861  0.0  10.0  17.0    37.0  24.086486
# ENE            30.0  10.833333  4.259540  0.0  11.0  18.0    30.0  23.333333
# ESE            23.0   8.739130  6.099310 -3.0  10.0  17.0    23.0  20.821739
# N              21.0   2.857143  5.092011 -2.0   1.0  17.0    21.0  18.538095
# NE             16.0  10.250000  5.259911  0.0  11.5  16.0    16.0  25.893750
#
#                              ... Evaporation                 Sunshine  \
#                   std   min  ...         std  min  50%   max    count
# WindGustDir                  ...
# E            5.142803  14.5  ...    2.611731  2.0  5.6  12.4     37.0
# ENE          5.760049  11.3  ...    2.116699  2.2  5.7  10.4     30.0
# ESE          6.522476  11.2  ...    3.230096  0.6  3.4  12.6     23.0
# N            6.660291   9.3  ...    2.787762  1.0  4.0  11.6     21.0
# NE           6.269234  14.0  ...    2.785558  1.4  6.1  11.4     16.0
#
#
#                  mean       std  min    50%   max
# WindGustDir
# E            8.600000  3.565966  0.0   9.20  13.0
# ENE          7.910000  3.634637  0.0   9.30  12.6
# ESE          5.978261  3.725582  0.0   7.10  12.5
# N            9.209524  2.615321  1.9   9.70  12.7
# NE           8.981250  4.171366  0.0  10.55  13.6
#
# [5 rows x 30 columns]

# %%
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation'], dtype='object')

# %%
columns_to_show=df.iloc[:,0:6].columns
df.groupby(['WindGustDir'])[columns_to_show].agg([np.mean, np.std, np.min, 
                                            np.max])
# Out:
#                MinTemp                        MaxTemp                        \
#                   mean       std amin amax       mean       std  amin  amax
# WindGustDir
# E             9.621622  4.934861    0   17  24.086486  5.142803  14.5  35.0
# ENE          10.833333  4.259540    0   18  23.333333  5.760049  11.3  34.1
# ESE           8.739130  6.099310   -3   17  20.821739  6.522476  11.2  35.0
# N             2.857143  5.092011   -2   17  18.538095  6.660291   9.3  33.2
# NE           10.250000  5.259911    0   16  25.893750  6.269234  14.0  34.2
# NNE           9.750000  3.845220    4   14  23.737500  7.125194  15.5  34.2
# NNW           5.750000  6.164886   -3   19  20.459091  5.742146  11.0  33.2
# NW            5.863014  5.421959   -5   18  19.478082  6.438367   7.6  34.9
# S             4.863636  5.166702   -2   16  17.013636  5.475077  10.7  30.0
# SE            6.833333  4.969605    0   15  18.491667  6.134323  12.4  35.2
# SSE           7.416667  7.452374   -3   17  18.750000  6.658760   9.7  35.8
# SSW           7.200000  6.833740   -3   14  23.400000  7.854298  15.1  34.7
# SW           14.000000  7.937254    5   20  27.000000  8.166395  19.5  35.7
# W             6.350000  5.769931   -2   15  19.510000  7.429096   9.7  33.8
# WNW           4.742857  5.112516   -2   17  17.537143  7.070531   8.8  33.8
# WSW          12.500000  0.707107   12   13  31.550000  0.353553  31.3  31.8
# nan           3.000000  5.196152    0    9  16.466667  3.743439  12.2  19.2
#
#              Rainfall                      Evaporation                       \
#                  mean       std amin  amax        mean       std amin  amax
# WindGustDir
# E            0.718919  2.784664  0.0  16.2    5.567568  2.611731  2.0  12.4
# ENE          1.720000  4.603027  0.0  17.4    5.860000  2.116699  2.2  10.4
# ESE          2.000000  5.635601  0.0  25.8    4.852174  3.230096  0.6  12.6
# N            0.400000  1.401428  0.0   6.4    4.047619  2.787762  1.0  11.6
# NE           1.425000  4.739550  0.0  18.8    6.075000  2.785558  1.4  11.4
# NNE          0.575000  1.471394  0.0   4.2    3.575000  3.220359  1.0   8.8
# NNW          1.463636  3.360723  0.0  14.4    4.368182  2.953577  0.6  10.4
# NW           2.084932  5.829705  0.0  39.8    4.084932  2.306252  0.2  10.4
# S            1.372727  2.638395  0.0  10.4    3.563636  2.094561  0.8   7.8
# SE           0.100000  0.289200  0.0   1.0    4.250000  2.250051  1.2   8.2
# SSE          2.616667  6.436520  0.0  22.6    4.416667  2.728247  0.2   9.4
# SSW          0.000000  0.000000  0.0   0.0    5.000000  2.024846  2.6   6.8
# SW           0.000000  0.000000  0.0   0.0    6.933333  5.987765  2.8  13.8
# W            2.380000  4.719456  0.0  19.8    3.380000  2.022921  0.6   7.8
# WNW          1.022857  3.424744  0.0  19.2    4.171429  2.655579  0.8   9.6
# WSW          0.000000  0.000000  0.0   0.0    6.300000  0.424264  6.0   6.6
# nan          0.000000  0.000000  0.0   0.0    2.000000  0.200000  1.8   2.2
#
#               Sunshine
#                   mean       std  amin  amax
# WindGustDir
# E             8.600000  3.565966   0.0  13.0
# ENE           7.910000  3.634637   0.0  12.6
# ESE           5.978261  3.725582   0.0  12.5
# N             9.209524  2.615321   1.9  12.7
# NE            8.981250  4.171366   0.0  13.6
# NNE           7.971429  4.080324   0.6  12.8
# NNW           8.018182  3.610468   0.0  13.6
# NW            8.108333  3.206013   0.0  13.1
# S             7.759091  3.272200   0.9  12.1
# SE            5.808333  3.954160   0.0  11.2
# SSE           7.100000  4.705509   0.2  13.3
# SSW           6.950000  1.279323   5.9   8.5
# SW            7.500000  1.126943   6.8   8.8
# W             7.090000  3.362001   0.0  11.3
# WNW           8.088571  3.087239   0.0  13.5
# WSW          11.450000  0.212132  11.3  11.6
# nan           8.300000  0.519615   7.7   8.6

# %%
pd.crosstab(df['RainToday'], df['RainTomorrow'])
# Out:
# RainTomorrow  False  True
# RainToday
# False           255     45
# True             45     21

# %%
pd.crosstab(df['RainToday'], df['RainTomorrow'],normalize=True)
# Out:
# RainTomorrow     False     True
# RainToday
# False         0.696721  0.122951
# True          0.122951  0.057377

# %%
 

df.pivot_table(['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine'],
               ['WindGustDir'], aggfunc='mean')
# Out:
#              Evaporation    MaxTemp    MinTemp  Rainfall   Sunshine
# WindGustDir
# E               5.567568  24.086486   9.621622  0.718919   8.600000
# ENE             5.860000  23.333333  10.833333  1.720000   7.910000
# ESE             4.852174  20.821739   8.739130  2.000000   5.978261
# N               4.047619  18.538095   2.857143  0.400000   9.209524
# NE              6.075000  25.893750  10.250000  1.425000   8.981250
# NNE             3.575000  23.737500   9.750000  0.575000   7.971429
# NNW             4.368182  20.459091   5.750000  1.463636   8.018182
# NW              4.084932  19.478082   5.863014  2.084932   8.108333
# S               3.563636  17.013636   4.863636  1.372727   7.759091
# SE              4.250000  18.491667   6.833333  0.100000   5.808333
# SSE             4.416667  18.750000   7.416667  2.616667   7.100000
# SSW             5.000000  23.400000   7.200000  0.000000   6.950000
# SW              6.933333  27.000000  14.000000  0.000000   7.500000
# W               3.380000  19.510000   6.350000  2.380000   7.090000
# WNW             4.171429  17.537143   4.742857  1.022857   8.088571
# WSW             6.300000  31.550000  12.500000  0.000000  11.450000
# nan             2.000000  16.466667   3.000000  0.000000   8.300000

# %%
total_pressure = df['Pressure9am'] + df['Pressure3pm']
df.insert(loc=len(df.columns), column='Total Pressure', value=total_pressure) 

df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8     24.3       0.0          3.4       6.3          NW
# 1       14     26.9       3.6          4.4       9.7         ENE
# 2       13     23.4       3.6          5.8       3.3          NW
# 3       13     15.5      39.8          7.2       9.1          NW
# 4        7     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Pressure9am  \
# 0           30.0         SW         NW           6.0  ...       1019.7
# 1           39.0          E          W           4.0  ...       1012.4
# 2           85.0          N        NNE           6.0  ...       1009.5
# 3           54.0        WNW          W          30.0  ...       1005.5
# 4           50.0        SSE        ESE          20.0  ...       1018.3
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1015.0         7         7     14.4     23.6      False      3.6
# 1       1008.4         5         3     17.5     25.7       True      3.6
# 2       1007.2         8         7     15.4     20.2       True     39.8
# 3       1007.0         2         7     13.5     14.1       True      2.8
# 4       1018.5         7         7     11.1     15.4       True      0.0
#
#    RainTomorrow  Total Pressure
# 0          True          2034.7
# 1          True          2020.8
# 2          True          2016.7
# 3          True          2012.5
# 4         False          2036.8
#
# [5 rows x 23 columns]

# %%
df.drop(['Total Pressure'], axis=1, inplace=True)

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0          8     24.3       0.0          3.4       6.3          NW
# 1         14     26.9       3.6          4.4       9.7         ENE
# 2         13     23.4       3.6          5.8       3.3          NW
# 3         13     15.5      39.8          7.2       9.1          NW
# 4          7     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361        9     30.7       0.0          7.6      12.1         NNW
# 362        7     28.4       0.0         11.6      12.7           N
# 363       12     19.9       0.0          8.4       5.3         ESE
# 364       12     26.9       0.0          5.0       7.1          NW
# 365       12     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# 1             39.0          E          W           4.0  ...           36
# 2             85.0          N        NNE           6.0  ...           69
# 3             54.0        WNW          W          30.0  ...           56
# 4             50.0        SSE        ESE          20.0  ...           49
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...           15
# 362           48.0        NNW        NNW           2.0  ...           22
# 363           43.0        ENE        ENE          11.0  ...           47
# 364           46.0        SSW        WNW           6.0  ...           39
# 365           78.0         NW        WNW          31.0  ...           13
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0         1019.7       1015.0         7         7     14.4     23.6
# 1         1012.4       1008.4         5         3     17.5     25.7
# 2         1009.5       1007.2         8         7     15.4     20.2
# 3         1005.5       1007.0         2         7     13.5     14.1
# 4         1018.3       1018.5         7         7     11.1     15.4
# ..           ...          ...       ...       ...      ...      ...
# 361       1016.1       1010.8         1         3     20.4     30.0
# 362       1020.0       1016.9         0         1     17.2     28.2
# 363       1024.0       1022.8         3         2     14.5     18.3
# 364       1021.0       1016.2         6         7     15.8     25.9
# 365       1009.6       1009.2         1         1     23.8     28.6
#
#      RainToday  RISK_MM  RainTomorrow
# 0        False      3.6          True
# 1         True      3.6          True
# 2         True     39.8          True
# 3         True      2.8          True
# 4         True      0.0         False
# ..         ...      ...           ...
# 361      False      0.0         False
# 362      False      0.0         False
# 363      False      0.0         False
# 364      False      0.0         False
# 365      False      0.0         False
#
# [366 rows x 22 columns]

# %%
df['Total Pressure']=df['Pressure9am'] + df['Pressure3pm']

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0          8     24.3       0.0          3.4       6.3          NW
# 1         14     26.9       3.6          4.4       9.7         ENE
# 2         13     23.4       3.6          5.8       3.3          NW
# 3         13     15.5      39.8          7.2       9.1          NW
# 4          7     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361        9     30.7       0.0          7.6      12.1         NNW
# 362        7     28.4       0.0         11.6      12.7           N
# 363       12     19.9       0.0          8.4       5.3         ESE
# 364       12     26.9       0.0          5.0       7.1          NW
# 365       12     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Pressure9am  \
# 0             30.0         SW         NW           6.0  ...       1019.7
# 1             39.0          E          W           4.0  ...       1012.4
# 2             85.0          N        NNE           6.0  ...       1009.5
# 3             54.0        WNW          W          30.0  ...       1005.5
# 4             50.0        SSE        ESE          20.0  ...       1018.3
# ..             ...        ...        ...           ...  ...          ...
# 361           76.0        SSE         NW           7.0  ...       1016.1
# 362           48.0        NNW        NNW           2.0  ...       1020.0
# 363           43.0        ENE        ENE          11.0  ...       1024.0
# 364           46.0        SSW        WNW           6.0  ...       1021.0
# 365           78.0         NW        WNW          31.0  ...       1009.6
#
#      Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0         1015.0         7         7     14.4     23.6      False      3.6
# 1         1008.4         5         3     17.5     25.7       True      3.6
# 2         1007.2         8         7     15.4     20.2       True     39.8
# 3         1007.0         2         7     13.5     14.1       True      2.8
# 4         1018.5         7         7     11.1     15.4       True      0.0
# ..           ...       ...       ...      ...      ...        ...      ...
# 361       1010.8         1         3     20.4     30.0      False      0.0
# 362       1016.9         0         1     17.2     28.2      False      0.0
# 363       1022.8         3         2     14.5     18.3      False      0.0
# 364       1016.2         6         7     15.8     25.9      False      0.0
# 365       1009.2         1         1     23.8     28.6      False      0.0
#
#      RainTomorrow  Total Pressure
# 0            True          2034.7
# 1            True          2020.8
# 2            True          2016.7
# 3            True          2012.5
# 4           False          2036.8
# ..            ...             ...
# 361         False          2026.9
# 362         False          2036.9
# 363         False          2046.8
# 364         False          2037.2
# 365         False          2018.8
#
# [366 rows x 23 columns]

# %%
sns.countplot(x='RainToday', hue='RainTomorrow', data=df);
